# %%
import pubchempy as pcp
import pandas as pd

# %%
df  = pd.read_csv(r'/home/lero/idrive/cmac/DDMAP/Stability_prediction_models/Smiles_calculator/apis.csv')

smiles = []

for index, row in df.iterrows():
    api_name = row['API']
    compounds = pcp.get_compounds(api_name, 'name')

    if compounds:
        smiles.append(compounds[0].connectivity_smiles)
    else:
        print(f'error retrieving {api_name}')
        smiles.append(None)

df['SMILES'] = smiles
print(df)
df.to_csv(r'/home/lero/idrive/cmac/DDMAP/Stability_prediction_models/Smiles_calculator/api_descriptors.csv', index=False)
# Out:
#                     API                                             SMILES
# 0         Acetaminophen                              CC(=O)NC1=CC=C(C=C1)O
# 1                    AZ         C1=CC=C2C(=C1)C(=O)C3=C(C2=O)C(=C(C=C3)O)O
# 2            Bifonazole  C1=CC=C(C=C1)C2=CC=C(C=C2)C(C3=CC=CC=C3)N4C=CN=C4
# 3         Carbamazepine               C1=CC=C2C(=C1)C=CC3=CC=CC=C3N2C(=O)N
# 4             Celecoxib  CC1=CC=C(C=C1)C2=CC(=NN2C3=CC=C(C=C3)S(=O)(=O)...
# 5         Chlorzoxazone                           C1=CC2=C(C=C1Cl)NC(=O)O2
# 6              Felbinac                  C1=CC=C(C=C1)C2=CC=C(C=C2)CC(=O)O
# 7           Fenofibrate  CC(C)OC(=O)C(C)(C)OC1=CC=C(C=C1)C(=O)C2=CC=C(C...
# 8       Flufenamic acid        C1=CC=C(C(=C1)C(=O)O)NC2=CC=CC(=C2)C(F)(F)F
# 9          Flurbiprofen              CC(C1=CC(=C(C=C1)C2=CC=CC=C2)F)C(=O)O
# 10        Glibenclamide  COC1=C(C=C(C=C1)Cl)C(=O)NCCC2=CC=C(C=C2)S(=O)(...
# 11            Glipizide  CC1=CN=C(C=N1)C(=O)NCCC2=CC=C(C=C2)S(=O)(=O)NC...
# 12         Griseofulvin  CC1CC(=O)C=C(C12C(=O)C3=C(O2)C(=C(C=C3OC)OC)Cl)OC
# 13          Haloperidol  C1CN(CCC1(C2=CC=C(C=C2)Cl)O)CCCC(=O)C3=CC=C(C=...
# 14  Hydrochlorothiazide          C1NC2=CC(=C(C=C2S(=O)(=O)N1)S(=O)(=O)N)Cl
# 15       Hydrocortisone    CC12CCC(=O)C=C1CCC3C2C(CC4(C3CCC4(C(=O)CO)O)C)O
# 16           Indapamide  CC1CC2=CC=CC=C2N1NC(=O)C3=CC(=C(C=C3)Cl)S(=O)(...
# 17         Indomethacin  CC1=C(C2=C(N1C(=O)C3=CC=C(C=C3)Cl)C=CC(=C2)OC)...
# 18         Ketoconazole  CC(=O)N1CCN(CC1)C2=CC=C(C=C2)OCC3COC(O3)(CN4C=...
# 19           Loratadine  CCOC(=O)N1CCC(=C2C3=C(CCC4=C2N=CC=C4)C=C(C=C3)...
# 20       Mefenamic acid                CC1=C(C(=CC=C1)NC2=CC=CC=C2C(=O)O)C
# 21             Naproxen                CC(C1=CC2=C(C=C1)C=C(C=C2)OC)C(=O)O
# 22           Nifedipine  CC1=C(C(C(=C(N1)C)C(=O)OC)C2=CC=CC=C2[N+](=O)[...
# 23           Nilutamide  CC1(C(=O)N(C(=O)N1)C2=CC(=C(C=C2)[N+](=O)[O-])...
# 24           Phenacetin                            CCOC1=CC=C(C=C1)NC(=O)C
# 25            Phenytoin          C1=CC=C(C=C1)C2(C(=O)NC(=O)N2)C3=CC=CC=C3
# 26            Piroxicam    CN1C(=C(C2=CC=CC=C2S1(=O)=O)O)C(=O)NC3=CC=CC=N3
# 27           Probenecid              CCCN(CCC)S(=O)(=O)C1=CC=C(C=C1)C(=O)O
# 28            Ritonavir  CC(C)C1=NC(=CS1)CN(C)C(=O)NC(C(C)C)C(=O)NC(CC2...
# 29       Spironolactone  CC(=O)SC1CC2=CC(=O)CCC2(C3C1C4CCC5(C4(CC3)C)CC...
# 30        Sulfamerazine             CC1=NC(=NC=C1)NS(=O)(=O)C2=CC=C(C=C2)N
# 31           Tinidazole              CCS(=O)(=O)CCN1C(=NC=C1[N+](=O)[O-])C
